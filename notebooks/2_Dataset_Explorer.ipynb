# %% [markdown]
# # Dataset Explorer
# Use this notebook to explore the samples dataset after it has been cleaned and organized.  Make sure to run Luigi to generate data before exploring it here.

# %%
import pandas as pd

# %% [markdown]
# # CONAGUA samples
# Use this section to explore the dataset of processed samples.

# %%
samples = pd.read_csv('../data/processed/samples.csv', index_col=0)

# Number of independent samples
samples.shape
# Out:
# (3951, 10)

# %%
# 10 random rows from the samples dataset
samples.sample(10)
# Out:
#              site    type   latitude   longitude  arsenic  cadmium   chromium  \
# 3371  OCPBC4287M1  Lagoon  32.158742 -115.300952    7.025     0.00   0.000000
# 523      DLDUR696    Well  25.062150 -103.728870   81.000     0.00   0.000000
# 3902  OCRBR5131M1   River  26.085370  -98.264890    0.000     0.00   5.171667
# 1927    DLTAB5356    Well  17.890833  -93.524722    0.000     0.00   0.000000
# 1314    DLMIC1772    Well  19.701130 -100.545570    7.300     0.33   9.200000
# 358      DLCOA490     Dam  29.519440 -101.252590    0.000     0.00   0.000000
# 420      DLCOL554   River  18.835180 -103.625050    0.000     0.00  14.116667
# 1510  DLPUE2022M1   River  19.115480  -98.227500    0.000     0.00   7.953333
# 3238    OCNOR4058     Dam  29.046880 -109.663000    0.000     0.00   0.000000
# 3622    OCPNO4678   River  25.708990 -108.341110    1.575     0.00   9.150000
#
#        mercury      lead  fluoride
# 3371  0.057500  0.000000       NaN
# 523   0.000000  0.000000    1231.3
# ...

# %% [markdown]
# # INEGI towns
# Use this section to explore the dataset of towns and their estimated contaminant exposure.

# %%
towns = pd.read_csv('../data/processed/towns_with_exposure.csv', index_col=0)

# %%
towns.shape
# Out:
# (43504, 14)

# %%
# 10 random rows from the towns dataset
towns.sample(10)
# Out:
#                  state            municipality  \
# 10292           Sonora  San Ignacio Río Muerto
# 26312          Hidalgo    Atotonilco el Grande
# 30417       Guanajuato                  Romita
# 17984       Nuevo León          Gral. Zaragoza
# 41140  Baja California                Ensenada
# 30086       Guanajuato                Moroleón
# 24798          Jalisco         Puerto Vallarta
# 7723           Tabasco                  Centla
# 35148          Chiapas               Cintalapa
# 11967  San Luis Potosí           Ciudad Valles
#
#                                            name  population   longitude  \
# 10292                                EL ALHUATE           9 -110.194722
# 26312                               SAUZ SABINO         318  -98.772778
# 30417                    SAN JOSÉ DE TUNA AGRIA          11 -101.696389
# 17984                               LA BARRANCA          16  -99.800556
# 41140  PARCELA NÚMERO TREINTA Y SEIS (TRIPLE A)          14 -116.559722
# ...
